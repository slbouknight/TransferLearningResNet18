# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product ">
# </a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="200" alt="cognitiveclass.ai logo">

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#download_data"> Download Data</a></li>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#data_class"> Dataset Class</a></li>
#     <li><a href="#Question_1">Question 1</a></li>
#     <li><a href="#Question_2">Question 2</a></li>
#     <li><a href="#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Out:
# --2023-04-05 02:46:21--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2598656062 (2.4G) [application/zip]
# Saving to: ‘Positive_tensors.zip’
#
# Positive_tensors.zi 100%[===================>]   2.42G  29.8MB/s    in 93s
#
# 2023-04-05 02:48:04 (26.6 MB/s) - ‘Positive_tensors.zip’ saved [2598656062/2598656062]

# %%
# !unzip -q Positive_tensors.zip

# %%
! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# !unzip -q Negative_tensors.zip
# Out:
# --2023-04-05 04:10:17--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2111408108 (2.0G) [application/zip]
# Saving to: ‘Negative_tensors.zip.1’
#
# Negative_tensors.zi 100%[===================>]   1.97G  32.4MB/s    in 64s

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.2.1)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torchvision) (1.16.0)
# Requirement already satisfied: numpy in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torchvision) (1.21.6)
# Requirement already satisfied: torch in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torchvision) (1.5.0)
# Requirement already satisfied: pillow>=4.1.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torchvision) (8.1.0)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from torch->torchvision) (0.18.2)

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="/resources/labs/Capstone"
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):
               
        image=torch.load(self.all_files[idx])
        y=self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y
    
print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
# Step 1: Load the pre-trained model resnet18
model = models.resnet18(pretrained=True)
# Type your code here

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
# Step 2: Set the parameter cannot be trained for the pre-trained model
for parameter in model.parameters():
    parameter.requires_grad = False
# Type your code here

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
model.fc = nn.Linear(512, 7)

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (fc): Linear(in_features=512, out_features=7, bias=True)
# )

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
# Step 1: Create the loss function

# Type your code here
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=100)
validation_loader = DataLoader(dataset=validation_dataset, batch_size=100)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters  for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs = 1
loss_list = []
accuracy_list = []
accuracy = 0
correct = 0
N_test = len(validation_dataset)
N_train = len(train_dataset)
start_time = time.time()
#n_epochs

print("Number of items in training set : ", N_train)
print("Number of items in testing set : ", N_test)

running_loss = 0
start_time = time.time()
for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):        
        print('-' * 30)
        print('Iteration (train phase) {}/{}'.format(i+1, int(N_train/100)))
        i_start_time = time.time()
            
        # set model to train 
        model.train() 
        
        # clear gradient 
        optimizer.zero_grad()
     
        # make a prediction 
        z = model(x)
   
        # calculate loss 
        loss = criterion(z, y) 
        # loss.requires_grad = True
    
        # calculate gradients of parameters 
        loss.backward()
        
        # update parameters 
        optimizer.step()
        
        loss_list.append(loss.data)
        print("Finished in {} (s)".format(time.time()-i_start_time))
    # end for
        
    correct=0
    for i, (x_test, y_test) in enumerate(validation_loader):
        print('-' * 30)
        print('Iteration (validation phase) {}/{}'.format(i+1, int(N_test/100)))
        i_start_time = time.time()

        # set model to eval 
        model.eval()
       
        # make a prediction 
        z = model(x_test)
        
        # find max 
        _, yhat = torch.max(z.data, 1)
       
       
        #Calculate misclassified  samples in mini-batch 
        #hint +=(yhat==y_test).sum().item()
        correct += (yhat==y_test).sum().item()  
        
        print("Finished in {} (s)".format(time.time()-i_start_time))
    # end for
    
    accuracy=correct/N_test
    print("Epoch %d - accuracy: %.3f" % (epoch+1, accuracy))
    
    accuracy_list.append(accuracy)
    print("-" * 72)
    
    # Save model
    model_file_path = model_path + "resnet18_trained_model_epoch_{}.pth".format(epoch+1)
    torch.save(model.state_dict(), model_file_path)
    
    # Duration for epoch
    print("Finished epoch {} in {} (s).".format(epoch+1, time.time()-start_time))
# Out:
# Number of items in training set :  30000
# Number of items in testing set :  10000
# ------------------------------
# Iteration (train phase) 1/300
# Finished in 12.875659704208374 (s)
# ------------------------------
# Iteration (train phase) 2/300
# Finished in 12.180135488510132 (s)
# ------------------------------
# Iteration (train phase) 3/300
# Finished in 12.619422674179077 (s)
# ------------------------------
# Iteration (train phase) 4/300
# Finished in 12.480582475662231 (s)
# ------------------------------
# Iteration (train phase) 5/300
# Finished in 13.161972999572754 (s)
# ------------------------------
# Iteration (train phase) 6/300
# Finished in 12.280271291732788 (s)
# ------------------------------
# Iteration (train phase) 7/300
# Finished in 11.161736726760864 (s)
# ------------------------------
# Iteration (train phase) 8/300
# Finished in 11.639066219329834 (s)
# ------------------------------
# Iteration (train phase) 9/300
# Finished in 12.783316612243652 (s)
# ------------------------------
# Iteration (train phase) 10/300
# Finished in 11.959824085235596 (s)
# ------------------------------
# Iteration (train phase) 11/300
# Finished in 12.295125722885132 (s)
# ------------------------------
# Iteration (train phase) 12/300
# Finished in 12.779779195785522 (s)
# ------------------------------
# Iteration (train phase) 13/300
# Finished in 11.321937799453735 (s)
# ------------------------------
# Iteration (train phase) 14/300
# Finished in 11.960549354553223 (s)
# ------------------------------
# Iteration (train phase) 15/300
# Finished in 12.301185131072998 (s)
# ------------------------------
# Iteration (train phase) 16/300
# Finished in 13.521076202392578 (s)
# ------------------------------
# Iteration (train phase) 17/300
# Finished in 12.403825759887695 (s)
# ------------------------------
# Iteration (train phase) 18/300
# Finished in 12.180165529251099 (s)
# ------------------------------
# Iteration (train phase) 19/300
# Finished in 12.432754755020142 (s)
# ------------------------------
# Iteration (train phase) 20/300
# Finished in 12.695452213287354 (s)
# ------------------------------
# Iteration (train phase) 21/300
# Finished in 13.081871747970581 (s)
# ------------------------------
# Iteration (train phase) 22/300
# Finished in 12.202006578445435 (s)
# ------------------------------
# Iteration (train phase) 23/300
# Finished in 13.625618934631348 (s)
# ------------------------------
# Iteration (train phase) 24/300
# Finished in 11.701584577560425 (s)
# ------------------------------
# Iteration (train phase) 25/300
# Finished in 11.580788135528564 (s)
# ------------------------------
# Iteration (train phase) 26/300
# Finished in 12.478126287460327 (s)
# ------------------------------
# Iteration (train phase) 27/300
# Finished in 12.355276823043823 (s)
# ------------------------------
# Iteration (train phase) 28/300
# Finished in 12.816527605056763 (s)
# ------------------------------
# Iteration (train phase) 29/300
# Finished in 13.440719604492188 (s)
# ------------------------------
# Iteration (train phase) 30/300
# Finished in 14.498528957366943 (s)
# ------------------------------
# Iteration (train phase) 31/300
# Finished in 11.660621404647827 (s)
# ------------------------------
# Iteration (train phase) 32/300
# Finished in 12.620731353759766 (s)
# ------------------------------
# Iteration (train phase) 33/300
# Finished in 13.81856918334961 (s)
# ------------------------------
# Iteration (train phase) 34/300
# Finished in 12.683671712875366 (s)
# ------------------------------
# Iteration (train phase) 35/300
# Finished in 13.29914140701294 (s)
# ------------------------------
# Iteration (train phase) 36/300
# Finished in 12.680673837661743 (s)
# ------------------------------
# Iteration (train phase) 37/300
# Finished in 12.360277652740479 (s)
# ------------------------------
# Iteration (train phase) 38/300
# Finished in 11.662219524383545 (s)
# ------------------------------
# Iteration (train phase) 39/300
# Finished in 13.040488243103027 (s)
# ------------------------------
# Iteration (train phase) 40/300
# Finished in 12.638965129852295 (s)
# ------------------------------
# Iteration (train phase) 41/300
# Finished in 12.263661623001099 (s)
# ------------------------------
# Iteration (train phase) 42/300
# Finished in 12.098285436630249 (s)
# ------------------------------
# Iteration (train phase) 43/300
# Finished in 13.256987810134888 (s)
# ------------------------------
# Iteration (train phase) 44/300
# Finished in 11.758490085601807 (s)
# ------------------------------
# Iteration (train phase) 45/300
# Finished in 13.036752462387085 (s)
# ------------------------------
# Iteration (train phase) 46/300
# Finished in 12.822819709777832 (s)
# ------------------------------
# Iteration (train phase) 47/300
# Finished in 13.340583324432373 (s)
# ------------------------------
# Iteration (train phase) 48/300
# Finished in 13.243713617324829 (s)
# ------------------------------
# Iteration (train phase) 49/300
# Finished in 12.962794780731201 (s)
# ------------------------------
# Iteration (train phase) 50/300
# Finished in 12.159420013427734 (s)
# ------------------------------
# Iteration (train phase) 51/300
# Finished in 11.680314540863037 (s)
# ------------------------------
# Iteration (train phase) 52/300
# Finished in 12.140979290008545 (s)
# ------------------------------
# Iteration (train phase) 53/300
# Finished in 13.919936656951904 (s)
# ------------------------------
# Iteration (train phase) 54/300
# Finished in 11.464784860610962 (s)
# ------------------------------
# Iteration (train phase) 55/300
# Finished in 12.283255100250244 (s)
# ------------------------------
# Iteration (train phase) 56/300
# Finished in 13.61843490600586 (s)
# ------------------------------
# Iteration (train phase) 57/300
# Finished in 12.276601076126099 (s)
# ------------------------------
# Iteration (train phase) 58/300
# Finished in 13.940401077270508 (s)
# ------------------------------
# Iteration (train phase) 59/300
# Finished in 12.68118691444397 (s)
# ------------------------------
# Iteration (train phase) 60/300
# Finished in 11.657372951507568 (s)
# ------------------------------
# Iteration (train phase) 61/300
# Finished in 11.220570087432861 (s)
# ------------------------------
# Iteration (train phase) 62/300
# Finished in 11.58069658279419 (s)
# ------------------------------
# Iteration (train phase) 63/300
# Finished in 13.4597008228302 (s)
# ------------------------------
# Iteration (train phase) 64/300
# Finished in 11.797004222869873 (s)
# ------------------------------
# Iteration (train phase) 65/300
# Finished in 11.605602502822876 (s)
# ------------------------------
# Iteration (train phase) 66/300
# Finished in 12.460785627365112 (s)
# ------------------------------
# Iteration (train phase) 67/300
# Finished in 13.041637897491455 (s)
# ------------------------------
# Iteration (train phase) 68/300
# Finished in 13.304583549499512 (s)
# ------------------------------
# Iteration (train phase) 69/300
# Finished in 12.615643501281738 (s)
# ------------------------------
# Iteration (train phase) 70/300
# Finished in 14.138580322265625 (s)
# ------------------------------
# Iteration (train phase) 71/300
# Finished in 13.242315530776978 (s)
# ------------------------------
# Iteration (train phase) 72/300
# Finished in 13.578179836273193 (s)
# ------------------------------
# Iteration (train phase) 73/300
# Finished in 12.961092472076416 (s)
# ------------------------------
# Iteration (train phase) 74/300
# Finished in 12.439619541168213 (s)
# ------------------------------
# Iteration (train phase) 75/300
# Finished in 13.041587352752686 (s)
# ------------------------------
# Iteration (train phase) 76/300
# Finished in 14.120567798614502 (s)
# ------------------------------
# Iteration (train phase) 77/300
# Finished in 12.600129127502441 (s)
# ------------------------------
# Iteration (train phase) 78/300
# Finished in 12.203843355178833 (s)
# ------------------------------
# Iteration (train phase) 79/300
# Finished in 14.083664655685425 (s)
# ------------------------------
# Iteration (train phase) 80/300
# Finished in 11.980308532714844 (s)
# ------------------------------
# Iteration (train phase) 81/300
# Finished in 12.720797300338745 (s)
# ------------------------------
# Iteration (train phase) 82/300
# Finished in 12.202895879745483 (s)
# ------------------------------
# Iteration (train phase) 83/300
# Finished in 13.055962562561035 (s)
# ------------------------------
# Iteration (train phase) 84/300
# Finished in 12.622190713882446 (s)
# ------------------------------
# Iteration (train phase) 85/300
# Finished in 12.380537509918213 (s)
# ------------------------------
# Iteration (train phase) 86/300
# Finished in 13.744652032852173 (s)
# ------------------------------
# Iteration (train phase) 87/300
# Finished in 13.016857862472534 (s)
# ------------------------------
# Iteration (train phase) 88/300
# Finished in 13.040244102478027 (s)
# ------------------------------
# Iteration (train phase) 89/300
# Finished in 14.319242238998413 (s)
# ------------------------------
# Iteration (train phase) 90/300
# Finished in 13.180346488952637 (s)
# ------------------------------
# Iteration (train phase) 91/300
# Finished in 13.403477191925049 (s)
# ------------------------------
# Iteration (train phase) 92/300
# Finished in 12.799160242080688 (s)
# ------------------------------
# Iteration (train phase) 93/300
# Finished in 13.60540509223938 (s)
# ------------------------------
# Iteration (train phase) 94/300
# Finished in 13.619008779525757 (s)
# ------------------------------
# Iteration (train phase) 95/300
# Finished in 12.880740880966187 (s)
# ------------------------------
# Iteration (train phase) 96/300
# Finished in 13.86312747001648 (s)
# ------------------------------
# Iteration (train phase) 97/300
# Finished in 14.521694421768188 (s)
# ------------------------------
# Iteration (train phase) 98/300
# Finished in 12.100568532943726 (s)
# ------------------------------
# Iteration (train phase) 99/300
# Finished in 12.080036401748657 (s)
# ------------------------------
# Iteration (train phase) 100/300
# Finished in 12.935810565948486 (s)
# ------------------------------
# Iteration (train phase) 101/300
# Finished in 12.985345602035522 (s)
# ------------------------------
# Iteration (train phase) 102/300
# Finished in 14.32260274887085 (s)
# ------------------------------
# Iteration (train phase) 103/300
# Finished in 12.642893314361572 (s)
# ------------------------------
# Iteration (train phase) 104/300
# Finished in 13.103007555007935 (s)
# ------------------------------
# Iteration (train phase) 105/300
# Finished in 13.17741060256958 (s)
# ------------------------------
# Iteration (train phase) 106/300
# Finished in 11.718722581863403 (s)
# ------------------------------
# Iteration (train phase) 107/300
# Finished in 11.895589828491211 (s)
# ------------------------------
# Iteration (train phase) 108/300
# Finished in 12.838670015335083 (s)
# ------------------------------
# Iteration (train phase) 109/300
# Finished in 14.122990608215332 (s)
# ------------------------------
# Iteration (train phase) 110/300
# Finished in 12.596374988555908 (s)
# ------------------------------
# Iteration (train phase) 111/300
# Finished in 13.46250867843628 (s)
# ------------------------------
# Iteration (train phase) 112/300
# Finished in 12.9240243434906 (s)
# ------------------------------
# Iteration (train phase) 113/300
# Finished in 12.140337944030762 (s)
# ------------------------------
# Iteration (train phase) 114/300
# Finished in 12.163069725036621 (s)
# ------------------------------
# Iteration (train phase) 115/300
# Finished in 13.105450630187988 (s)
# ------------------------------
# Iteration (train phase) 116/300
# Finished in 12.042287349700928 (s)
# ------------------------------
# Iteration (train phase) 117/300
# Finished in 12.46104383468628 (s)
# ------------------------------
# Iteration (train phase) 118/300
# Finished in 12.75502324104309 (s)
# ------------------------------
# Iteration (train phase) 119/300
# Finished in 12.397929668426514 (s)
# ------------------------------
# Iteration (train phase) 120/300
# Finished in 11.559693098068237 (s)
# ------------------------------
# Iteration (train phase) 121/300
# Finished in 12.622546195983887 (s)
# ------------------------------
# Iteration (train phase) 122/300
# Finished in 12.865589380264282 (s)
# ------------------------------
# Iteration (train phase) 123/300
# Finished in 13.101440668106079 (s)
# ------------------------------
# Iteration (train phase) 124/300
# Finished in 11.259076833724976 (s)
# ------------------------------
# Iteration (train phase) 125/300
# Finished in 12.597079277038574 (s)
# ------------------------------
# Iteration (train phase) 126/300
# Finished in 14.099002838134766 (s)
# ------------------------------
# Iteration (train phase) 127/300
# Finished in 14.657102108001709 (s)
# ------------------------------
# Iteration (train phase) 128/300
# Finished in 13.399468421936035 (s)
# ------------------------------
# Iteration (train phase) 129/300
# Finished in 12.103862285614014 (s)
# ------------------------------
# Iteration (train phase) 130/300
# Finished in 11.179092407226562 (s)
# ------------------------------
# Iteration (train phase) 131/300
# Finished in 12.882359266281128 (s)
# ------------------------------
# Iteration (train phase) 132/300
# Finished in 11.325591564178467 (s)
# ------------------------------
# Iteration (train phase) 133/300
# Finished in 12.218536853790283 (s)
# ------------------------------
# Iteration (train phase) 134/300
# Finished in 14.583329916000366 (s)
# ------------------------------
# Iteration (train phase) 135/300
# Finished in 12.824922323226929 (s)
# ------------------------------
# Iteration (train phase) 136/300
# Finished in 11.463226556777954 (s)
# ------------------------------
# Iteration (train phase) 137/300
# Finished in 12.462687969207764 (s)
# ------------------------------
# Iteration (train phase) 138/300
# Finished in 11.06149697303772 (s)
# ------------------------------
# Iteration (train phase) 139/300
# Finished in 10.903255462646484 (s)
# ------------------------------
# Iteration (train phase) 140/300
# Finished in 12.836591958999634 (s)
# ------------------------------
# Iteration (train phase) 141/300
# Finished in 13.464809656143188 (s)
# ------------------------------
# Iteration (train phase) 142/300
# Finished in 11.323923349380493 (s)
# ------------------------------
# Iteration (train phase) 143/300
# Finished in 11.742096662521362 (s)
# ------------------------------
# Iteration (train phase) 144/300
# Finished in 12.118324995040894 (s)
# ------------------------------
# Iteration (train phase) 145/300
# Finished in 12.317529678344727 (s)
# ------------------------------
# Iteration (train phase) 146/300
# Finished in 11.681375503540039 (s)
# ------------------------------
# Iteration (train phase) 147/300
# Finished in 12.722100973129272 (s)
# ------------------------------
# Iteration (train phase) 148/300
# Finished in 11.740155458450317 (s)
# ------------------------------
# Iteration (train phase) 149/300
# Finished in 12.71683931350708 (s)
# ------------------------------
# Iteration (train phase) 150/300
# Finished in 13.659847736358643 (s)
# ------------------------------
# Iteration (train phase) 151/300
# Finished in 15.043763399124146 (s)
# ------------------------------
# Iteration (train phase) 152/300
# Finished in 11.818869590759277 (s)
# ------------------------------
# Iteration (train phase) 153/300
# Finished in 11.160011291503906 (s)
# ------------------------------
# Iteration (train phase) 154/300
# Finished in 10.800706624984741 (s)
# ------------------------------
# Iteration (train phase) 155/300
# Finished in 11.58185076713562 (s)
# ------------------------------
# Iteration (train phase) 156/300
# Finished in 12.520570278167725 (s)
# ------------------------------
# Iteration (train phase) 157/300
# Finished in 13.120444059371948 (s)
# ------------------------------
# Iteration (train phase) 158/300
# Finished in 13.760095834732056 (s)
# ------------------------------
# Iteration (train phase) 159/300
# Finished in 11.68428087234497 (s)
# ------------------------------
# Iteration (train phase) 160/300
# Finished in 12.18165636062622 (s)
# ------------------------------
# Iteration (train phase) 161/300
# Finished in 12.260427474975586 (s)
# ------------------------------
# Iteration (train phase) 162/300
# Finished in 12.76271367073059 (s)
# ------------------------------
# Iteration (train phase) 163/300
# Finished in 12.240925073623657 (s)
# ------------------------------
# Iteration (train phase) 164/300
# Finished in 13.062727212905884 (s)
# ------------------------------
# Iteration (train phase) 165/300
# Finished in 12.400496006011963 (s)
# ------------------------------
# Iteration (train phase) 166/300
# Finished in 11.877331733703613 (s)
# ------------------------------
# Iteration (train phase) 167/300
# Finished in 12.819188356399536 (s)
# ------------------------------
# Iteration (train phase) 168/300
# Finished in 12.898669958114624 (s)
# ------------------------------
# Iteration (train phase) 169/300
# Finished in 12.243451356887817 (s)
# ------------------------------
# Iteration (train phase) 170/300
# Finished in 11.600452661514282 (s)
# ------------------------------
# Iteration (train phase) 171/300
# Finished in 13.097327709197998 (s)
# ------------------------------
# Iteration (train phase) 172/300
# Finished in 12.101293563842773 (s)
# ------------------------------
# Iteration (train phase) 173/300
# Finished in 12.74298644065857 (s)
# ------------------------------
# Iteration (train phase) 174/300
# Finished in 12.74026870727539 (s)
# ------------------------------
# Iteration (train phase) 175/300
# Finished in 14.239570617675781 (s)
# ------------------------------
# Iteration (train phase) 176/300
# Finished in 14.42001748085022 (s)
# ------------------------------
# Iteration (train phase) 177/300
# Finished in 12.357392072677612 (s)
# ------------------------------
# Iteration (train phase) 178/300
# Finished in 13.40011191368103 (s)
# ------------------------------
# Iteration (train phase) 179/300
# Finished in 12.575455665588379 (s)
# ------------------------------
# Iteration (train phase) 180/300
# Finished in 12.481172323226929 (s)
# ------------------------------
# Iteration (train phase) 181/300
# Finished in 13.140881538391113 (s)
# ------------------------------
# Iteration (train phase) 182/300
# Finished in 12.840884685516357 (s)
# ------------------------------
# Iteration (train phase) 183/300
# Finished in 13.480082988739014 (s)
# ------------------------------
# Iteration (train phase) 184/300
# Finished in 13.600908041000366 (s)
# ------------------------------
# Iteration (train phase) 185/300
# Finished in 11.824382066726685 (s)
# ------------------------------
# Iteration (train phase) 186/300
# Finished in 12.318809747695923 (s)
# ------------------------------
# Iteration (train phase) 187/300
# Finished in 12.822366952896118 (s)
# ------------------------------
# Iteration (train phase) 188/300
# Finished in 13.158479928970337 (s)
# ------------------------------
# Iteration (train phase) 189/300
# Finished in 11.78056001663208 (s)
# ------------------------------
# Iteration (train phase) 190/300
# Finished in 13.421945810317993 (s)
# ------------------------------
# Iteration (train phase) 191/300
# Finished in 15.219180345535278 (s)
# ------------------------------
# Iteration (train phase) 192/300
# Finished in 12.535254001617432 (s)
# ------------------------------
# Iteration (train phase) 193/300
# Finished in 13.558249235153198 (s)
# ------------------------------
# Iteration (train phase) 194/300
# Finished in 14.382621765136719 (s)
# ------------------------------
# Iteration (train phase) 195/300
# Finished in 13.522524356842041 (s)
# ------------------------------
# Iteration (train phase) 196/300
# Finished in 13.200990200042725 (s)
# ------------------------------
# Iteration (train phase) 197/300
# Finished in 14.975088119506836 (s)
# ------------------------------
# Iteration (train phase) 198/300
# Finished in 13.92222285270691 (s)
# ------------------------------
# Iteration (train phase) 199/300
# Finished in 12.457927227020264 (s)
# ------------------------------
# Iteration (train phase) 200/300
# Finished in 11.553383350372314 (s)
# ------------------------------
# Iteration (train phase) 201/300
# Finished in 12.9392831325531 (s)
# ------------------------------
# Iteration (train phase) 202/300
# Finished in 11.996362447738647 (s)
# ------------------------------
# Iteration (train phase) 203/300
# Finished in 11.798762321472168 (s)
# ------------------------------
# Iteration (train phase) 204/300
# Finished in 13.237573385238647 (s)
# ------------------------------
# Iteration (train phase) 205/300
# Finished in 10.879644393920898 (s)
# ------------------------------
# Iteration (train phase) 206/300
# Finished in 12.701473712921143 (s)
# ------------------------------
# Iteration (train phase) 207/300
# Finished in 13.397595882415771 (s)
# ------------------------------
# Iteration (train phase) 208/300
# Finished in 12.319770097732544 (s)
# ------------------------------
# Iteration (train phase) 209/300
# Finished in 12.880325078964233 (s)
# ------------------------------
# Iteration (train phase) 210/300
# Finished in 12.580796957015991 (s)
# ------------------------------
# Iteration (train phase) 211/300
# Finished in 13.082216739654541 (s)
# ------------------------------
# Iteration (train phase) 212/300
# Finished in 13.423016548156738 (s)
# ------------------------------
# Iteration (train phase) 213/300
# Finished in 12.741486549377441 (s)
# ------------------------------
# Iteration (train phase) 214/300
# Finished in 12.525190353393555 (s)
# ------------------------------
# Iteration (train phase) 215/300
# Finished in 14.121536254882812 (s)
# ------------------------------
# Iteration (train phase) 216/300
# Finished in 12.663212299346924 (s)
# ------------------------------
# Iteration (train phase) 217/300
# Finished in 13.158802509307861 (s)
# ------------------------------
# Iteration (train phase) 218/300
# Finished in 12.721449851989746 (s)
# ------------------------------
# Iteration (train phase) 219/300
# Finished in 13.579627513885498 (s)
# ------------------------------
# Iteration (train phase) 220/300
# Finished in 14.09918737411499 (s)
# ------------------------------
# Iteration (train phase) 221/300
# Finished in 11.941227197647095 (s)
# ------------------------------
# Iteration (train phase) 222/300
# Finished in 12.477832794189453 (s)
# ------------------------------
# Iteration (train phase) 223/300
# Finished in 12.301628351211548 (s)
# ------------------------------
# Iteration (train phase) 224/300
# Finished in 13.275757789611816 (s)
# ------------------------------
# Iteration (train phase) 225/300
# Finished in 13.88346791267395 (s)
# ------------------------------
# Iteration (train phase) 226/300
# Finished in 12.75710415840149 (s)
# ------------------------------
# Iteration (train phase) 227/300
# Finished in 11.58005952835083 (s)
# ------------------------------
# Iteration (train phase) 228/300
# Finished in 12.556637048721313 (s)
# ------------------------------
# Iteration (train phase) 229/300
# Finished in 12.360002517700195 (s)
# ------------------------------
# Iteration (train phase) 230/300
# Finished in 12.87678861618042 (s)
# ------------------------------
# Iteration (train phase) 231/300
# Finished in 11.701894521713257 (s)
# ------------------------------
# Iteration (train phase) 232/300
# Finished in 12.041712522506714 (s)
# ------------------------------
# Iteration (train phase) 233/300
# Finished in 12.535974264144897 (s)
# ------------------------------
# Iteration (train phase) 234/300
# Finished in 12.479017496109009 (s)
# ------------------------------
# Iteration (train phase) 235/300
# Finished in 12.002387762069702 (s)
# ------------------------------
# Iteration (train phase) 236/300
# Finished in 13.29906439781189 (s)
# ------------------------------
# Iteration (train phase) 237/300
# Finished in 12.757942199707031 (s)
# ------------------------------
# Iteration (train phase) 238/300
# Finished in 12.294649124145508 (s)
# ------------------------------
# Iteration (train phase) 239/300
# Finished in 12.140294313430786 (s)
# ------------------------------
# Iteration (train phase) 240/300
# Finished in 11.1765775680542 (s)
# ------------------------------
# Iteration (train phase) 241/300
# Finished in 11.52003526687622 (s)
# ------------------------------
# Iteration (train phase) 242/300
# Finished in 12.363513231277466 (s)
# ------------------------------
# Iteration (train phase) 243/300
# Finished in 12.378319263458252 (s)
# ------------------------------
# Iteration (train phase) 244/300
# Finished in 11.923369884490967 (s)
# ------------------------------
# Iteration (train phase) 245/300
# Finished in 11.742217540740967 (s)
# ------------------------------
# Iteration (train phase) 246/300
# Finished in 11.783898115158081 (s)
# ------------------------------
# Iteration (train phase) 247/300
# Finished in 12.082154989242554 (s)
# ------------------------------
# Iteration (train phase) 248/300
# Finished in 10.998790740966797 (s)
# ------------------------------
# Iteration (train phase) 249/300
# Finished in 11.321252822875977 (s)
# ------------------------------
# Iteration (train phase) 250/300
# Finished in 12.85939335823059 (s)
# ------------------------------
# Iteration (train phase) 251/300
# Finished in 11.20050048828125 (s)
# ------------------------------
# Iteration (train phase) 252/300
# Finished in 11.499146699905396 (s)
# ------------------------------
# Iteration (train phase) 253/300
# Finished in 13.081316709518433 (s)
# ------------------------------
# Iteration (train phase) 254/300
# Finished in 12.038656949996948 (s)
# ------------------------------
# Iteration (train phase) 255/300
# Finished in 11.217256307601929 (s)
# ------------------------------
# Iteration (train phase) 256/300
# Finished in 11.722401142120361 (s)
# ------------------------------
# Iteration (train phase) 257/300
# Finished in 11.959714412689209 (s)
# ------------------------------
# Iteration (train phase) 258/300
# Finished in 11.899855136871338 (s)
# ------------------------------
# Iteration (train phase) 259/300
# Finished in 12.77959394454956 (s)
# ------------------------------
# Iteration (train phase) 260/300
# Finished in 12.101152896881104 (s)
# ------------------------------
# Iteration (train phase) 261/300
# Finished in 11.420687913894653 (s)
# ------------------------------
# Iteration (train phase) 262/300
# Finished in 11.600330829620361 (s)
# ------------------------------
# Iteration (train phase) 263/300
# Finished in 12.339224338531494 (s)
# ------------------------------
# Iteration (train phase) 264/300
# Finished in 11.819131135940552 (s)
# ------------------------------
# Iteration (train phase) 265/300
# Finished in 13.27731966972351 (s)
# ------------------------------
# Iteration (train phase) 266/300
# Finished in 12.340166330337524 (s)
# ------------------------------
# Iteration (train phase) 267/300
# Finished in 12.678350687026978 (s)
# ------------------------------
# Iteration (train phase) 268/300
# Finished in 12.120028495788574 (s)
# ------------------------------
# Iteration (train phase) 269/300
# Finished in 12.868818998336792 (s)
# ------------------------------
# Iteration (train phase) 270/300
# Finished in 13.56262469291687 (s)
# ------------------------------
# Iteration (train phase) 271/300
# Finished in 12.903583288192749 (s)
# ------------------------------
# Iteration (train phase) 272/300
# Finished in 13.496649742126465 (s)
# ------------------------------
# Iteration (train phase) 273/300
# Finished in 12.700237512588501 (s)
# ------------------------------
# Iteration (train phase) 274/300
# Finished in 11.13483190536499 (s)
# ------------------------------
# Iteration (train phase) 275/300
# Finished in 11.9641432762146 (s)
# ------------------------------
# Iteration (train phase) 276/300
# Finished in 12.558570623397827 (s)
# ------------------------------
# Iteration (train phase) 277/300
# Finished in 13.221637487411499 (s)
# ------------------------------
# Iteration (train phase) 278/300
# Finished in 12.578705549240112 (s)
# ------------------------------
# Iteration (train phase) 279/300
# Finished in 11.421244859695435 (s)
# ------------------------------
# Iteration (train phase) 280/300
# Finished in 12.864343643188477 (s)
# ------------------------------
# Iteration (train phase) 281/300
# Finished in 13.660687923431396 (s)
# ------------------------------
# Iteration (train phase) 282/300
# Finished in 12.498770713806152 (s)
# ------------------------------
# Iteration (train phase) 283/300
# Finished in 13.037730932235718 (s)
# ------------------------------
# Iteration (train phase) 284/300
# Finished in 12.220873832702637 (s)
# ------------------------------
# Iteration (train phase) 285/300
# Finished in 12.84248161315918 (s)
# ------------------------------
# Iteration (train phase) 286/300
# Finished in 13.797017097473145 (s)
# ------------------------------
# Iteration (train phase) 287/300
# Finished in 12.741764307022095 (s)
# ------------------------------
# Iteration (train phase) 288/300
# Finished in 11.416990041732788 (s)
# ------------------------------
# Iteration (train phase) 289/300
# Finished in 12.375075101852417 (s)
# ------------------------------
# Iteration (train phase) 290/300
# Finished in 11.326038360595703 (s)
# ------------------------------
# Iteration (train phase) 291/300
# Finished in 11.280830383300781 (s)
# ------------------------------
# Iteration (train phase) 292/300
# Finished in 12.102222442626953 (s)
# ------------------------------
# Iteration (train phase) 293/300
# Finished in 13.474751472473145 (s)
# ------------------------------
# Iteration (train phase) 294/300
# Finished in 11.642382144927979 (s)
# ------------------------------
# Iteration (train phase) 295/300
# Finished in 13.10219669342041 (s)
# ------------------------------
# Iteration (train phase) 296/300
# Finished in 12.842424392700195 (s)
# ------------------------------
# Iteration (train phase) 297/300
# Finished in 12.362051010131836 (s)
# ------------------------------
# Iteration (train phase) 298/300
# Finished in 13.28524398803711 (s)
# ------------------------------
# Iteration (train phase) 299/300
# Finished in 13.38065767288208 (s)
# ------------------------------
# Iteration (train phase) 300/300
# Finished in 12.275702476501465 (s)
# ------------------------------
# Iteration (validation phase) 1/100
# Finished in 11.081696510314941 (s)
# ------------------------------
# Iteration (validation phase) 2/100
# Finished in 10.977380990982056 (s)
# ------------------------------
# Iteration (validation phase) 3/100
# Finished in 11.399688243865967 (s)
# ------------------------------
# Iteration (validation phase) 4/100
# Finished in 11.401044130325317 (s)
# ------------------------------
# Iteration (validation phase) 5/100
# Finished in 12.003441333770752 (s)
# ------------------------------
# Iteration (validation phase) 6/100
# Finished in 12.699073314666748 (s)
# ------------------------------
# Iteration (validation phase) 7/100
# Finished in 11.934403657913208 (s)
# ------------------------------
# Iteration (validation phase) 8/100
# Finished in 11.438364267349243 (s)
# ------------------------------
# Iteration (validation phase) 9/100
# Finished in 12.297471046447754 (s)
# ------------------------------
# Iteration (validation phase) 10/100
# Finished in 11.02144742012024 (s)
# ------------------------------
# Iteration (validation phase) 11/100
# Finished in 11.11780309677124 (s)
# ------------------------------
# Iteration (validation phase) 12/100
# Finished in 12.395178318023682 (s)
# ------------------------------
# Iteration (validation phase) 13/100
# Finished in 11.741400241851807 (s)
# ------------------------------
# Iteration (validation phase) 14/100
# Finished in 10.883057117462158 (s)
# ------------------------------
# Iteration (validation phase) 15/100
# Finished in 10.717105627059937 (s)
# ------------------------------
# Iteration (validation phase) 16/100
# Finished in 10.359850645065308 (s)
# ------------------------------
# Iteration (validation phase) 17/100
# Finished in 11.638406753540039 (s)
# ------------------------------
# Iteration (validation phase) 18/100
# Finished in 10.280960321426392 (s)
# ------------------------------
# Iteration (validation phase) 19/100
# Finished in 9.299555540084839 (s)
# ------------------------------
# Iteration (validation phase) 20/100
# Finished in 10.258782148361206 (s)
# ------------------------------
# Iteration (validation phase) 21/100
# Finished in 9.514520645141602 (s)
# ------------------------------
# Iteration (validation phase) 22/100
# Finished in 10.822564363479614 (s)
# ------------------------------
# Iteration (validation phase) 23/100
# Finished in 10.540068626403809 (s)
# ------------------------------
# Iteration (validation phase) 24/100
# Finished in 11.658326625823975 (s)
# ------------------------------
# Iteration (validation phase) 25/100
# Finished in 10.799500942230225 (s)
# ------------------------------
# Iteration (validation phase) 26/100
# Finished in 11.792761325836182 (s)
# ------------------------------
# Iteration (validation phase) 27/100
# Finished in 10.855133771896362 (s)
# ------------------------------
# Iteration (validation phase) 28/100
# Finished in 12.642427921295166 (s)
# ------------------------------
# Iteration (validation phase) 29/100
# Finished in 11.621036529541016 (s)
# ------------------------------
# Iteration (validation phase) 30/100
# Finished in 10.280416250228882 (s)
# ------------------------------
# Iteration (validation phase) 31/100
# Finished in 11.819700002670288 (s)
# ------------------------------
# Iteration (validation phase) 32/100
# Finished in 10.418788433074951 (s)
# ------------------------------
# Iteration (validation phase) 33/100
# Finished in 11.058414697647095 (s)
# ------------------------------
# Iteration (validation phase) 34/100
# Finished in 10.878014087677002 (s)
# ------------------------------
# Iteration (validation phase) 35/100
# Finished in 12.061389684677124 (s)
# ------------------------------
# Iteration (validation phase) 36/100
# Finished in 10.820106983184814 (s)
# ------------------------------
# Iteration (validation phase) 37/100
# Finished in 10.710754871368408 (s)
# ------------------------------
# Iteration (validation phase) 38/100
# Finished in 10.936584234237671 (s)
# ------------------------------
# Iteration (validation phase) 39/100
# Finished in 10.801407814025879 (s)
# ------------------------------
# Iteration (validation phase) 40/100
# Finished in 9.717432022094727 (s)
# ------------------------------
# Iteration (validation phase) 41/100
# Finished in 11.02036452293396 (s)
# ------------------------------
# Iteration (validation phase) 42/100
# Finished in 11.121620416641235 (s)
# ------------------------------
# Iteration (validation phase) 43/100
# Finished in 11.980201721191406 (s)
# ------------------------------
# Iteration (validation phase) 44/100
# Finished in 10.579253196716309 (s)
# ------------------------------
# Iteration (validation phase) 45/100
# Finished in 11.594373226165771 (s)
# ------------------------------
# Iteration (validation phase) 46/100
# Finished in 11.721531391143799 (s)
# ------------------------------
# Iteration (validation phase) 47/100
# Finished in 11.71513295173645 (s)
# ------------------------------
# Iteration (validation phase) 48/100
# Finished in 10.497942209243774 (s)
# ------------------------------
# Iteration (validation phase) 49/100
# Finished in 12.040993928909302 (s)
# ------------------------------
# Iteration (validation phase) 50/100
# Finished in 10.355891942977905 (s)
# ------------------------------
# Iteration (validation phase) 51/100
# Finished in 10.140132904052734 (s)
# ------------------------------
# Iteration (validation phase) 52/100
# Finished in 10.659974098205566 (s)
# ------------------------------
# Iteration (validation phase) 53/100
# Finished in 11.478049516677856 (s)
# ------------------------------
# Iteration (validation phase) 54/100
# Finished in 10.920137882232666 (s)
# ------------------------------
# Iteration (validation phase) 55/100
# Finished in 11.65787148475647 (s)
# ------------------------------
# Iteration (validation phase) 56/100
# Finished in 12.379376888275146 (s)
# ------------------------------
# Iteration (validation phase) 57/100
# Finished in 11.599034786224365 (s)
# ------------------------------
# Iteration (validation phase) 58/100
# Finished in 10.354890584945679 (s)
# ------------------------------
# Iteration (validation phase) 59/100
# Finished in 10.819732904434204 (s)
# ------------------------------
# Iteration (validation phase) 60/100
# Finished in 11.800414800643921 (s)
# ------------------------------
# Iteration (validation phase) 61/100
# Finished in 10.68281102180481 (s)
# ------------------------------
# Iteration (validation phase) 62/100
# Finished in 10.59830641746521 (s)
# ------------------------------
# Iteration (validation phase) 63/100
# Finished in 11.219414710998535 (s)
# ------------------------------
# Iteration (validation phase) 64/100
# Finished in 11.435967445373535 (s)
# ------------------------------
# Iteration (validation phase) 65/100
# Finished in 11.818629503250122 (s)
# ------------------------------
# Iteration (validation phase) 66/100
# Finished in 11.237133264541626 (s)
# ------------------------------
# Iteration (validation phase) 67/100
# Finished in 10.900917768478394 (s)
# ------------------------------
# Iteration (validation phase) 68/100
# Finished in 10.80103063583374 (s)
# ------------------------------
# Iteration (validation phase) 69/100
# Finished in 10.778147459030151 (s)
# ------------------------------
# Iteration (validation phase) 70/100
# Finished in 12.182591199874878 (s)
# ------------------------------
# Iteration (validation phase) 71/100
# Finished in 10.143344163894653 (s)
# ------------------------------
# Iteration (validation phase) 72/100
# Finished in 10.67616605758667 (s)
# ------------------------------
# Iteration (validation phase) 73/100
# Finished in 11.617493391036987 (s)
# ------------------------------
# Iteration (validation phase) 74/100
# Finished in 12.581459760665894 (s)
# ------------------------------
# Iteration (validation phase) 75/100
# Finished in 10.284768342971802 (s)
# ------------------------------
# Iteration (validation phase) 76/100
# Finished in 10.900060653686523 (s)
# ------------------------------
# Iteration (validation phase) 77/100
# Finished in 12.596864223480225 (s)
# ------------------------------
# Iteration (validation phase) 78/100
# Finished in 10.302602767944336 (s)
# ------------------------------
# Iteration (validation phase) 79/100
# Finished in 11.298298120498657 (s)
# ------------------------------
# Iteration (validation phase) 80/100
# Finished in 11.336175680160522 (s)
# ------------------------------
# Iteration (validation phase) 81/100
# Finished in 11.859641551971436 (s)
# ------------------------------
# Iteration (validation phase) 82/100
# Finished in 11.637499809265137 (s)
# ------------------------------
# Iteration (validation phase) 83/100
# Finished in 10.39822244644165 (s)
# ------------------------------
# Iteration (validation phase) 84/100
# Finished in 11.080164909362793 (s)
# ------------------------------
# Iteration (validation phase) 85/100
# Finished in 11.834322214126587 (s)
# ------------------------------
# Iteration (validation phase) 86/100
# Finished in 11.640361309051514 (s)
# ------------------------------
# Iteration (validation phase) 87/100
# Finished in 12.178652048110962 (s)
# ------------------------------
# Iteration (validation phase) 88/100
# Finished in 11.818772792816162 (s)
# ------------------------------
# Iteration (validation phase) 89/100
# Finished in 11.780009508132935 (s)
# ------------------------------
# Iteration (validation phase) 90/100
# Finished in 10.52136516571045 (s)
# ------------------------------
# Iteration (validation phase) 91/100
# Finished in 12.542790412902832 (s)
# ------------------------------
# Iteration (validation phase) 92/100
# Finished in 11.261829137802124 (s)
# ------------------------------
# Iteration (validation phase) 93/100
# Finished in 10.140716791152954 (s)
# ------------------------------
# Iteration (validation phase) 94/100
# Finished in 11.552387237548828 (s)
# ------------------------------
# Iteration (validation phase) 95/100
# Finished in 11.443950176239014 (s)
# ------------------------------
# Iteration (validation phase) 96/100
# Finished in 11.11564564704895 (s)
# ------------------------------
# Iteration (validation phase) 97/100
# Finished in 10.981364011764526 (s)
# ------------------------------
# Iteration (validation phase) 98/100
# Finished in 13.135366201400757 (s)
# ------------------------------
# Iteration (validation phase) 99/100
# Finished in 11.156295537948608 (s)
# ------------------------------
# Iteration (validation phase) 100/100
# Finished in 11.51585865020752 (s)
# Epoch 1 - accuracy: 0.994
# ------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1147/2564560155.py in <module>
#      73
#      74     # Save model
# ---> 75     model_file_path = model_path + "resnet18_trained_model_epoch_{}.pth".format(epoch+1)
#      76     torch.save(model.state_dict(), model_file_path)
#      77
#
# NameError: name 'model_path' is not defined

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.9939

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
count = 0
misclassified_num = 4  # first four mis-classified samples
validation_loader_batch_one = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=1)

for i, (x_test, y_test) in enumerate(validation_loader_batch_one):
    # set model to eval
    model.eval()
    
    # make a prediction
    z = model(x_test)
    
    # get the max
    _, yhat = torch.max(z.data, 1)
    
    # printing misclassified samples
    if yhat != y_test:
        print("Sample : {}; Predicted Value: {}; Actual Value: {}".format(str(i), str(y_test), str(yhat)))
        count += 1
        if count >= misclassified_num:
            break
# Out:
# Sample : 22; Predicted Value: tensor([1]); Actual Value: tensor([0])
# Sample : 101; Predicted Value: tensor([0]); Actual Value: tensor([1])
# Sample : 213; Predicted Value: tensor([0]); Actual Value: tensor([1])
# Sample : 264; Predicted Value: tensor([1]); Actual Value: tensor([0])

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-21  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">MIT License</a>.
